# %%
'''
# %time: Time the execution of a single statement
# %timeit: Time repeated execution of a single statement for more accuracy
# %prun: Run code with the profiler
# %lprun: Run code with the line-by-line profiler
# %memit: Measure the memory use of a single statement
# %mprun: Run code with the line-by-line memory profiler

https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html
'''

#!/usr/bin/python

from math import ceil,sqrt

def testEuler():
    @profile
    def gen_primes(n):
        l = range(2,n)
        primes = []
        for j in range(0,len(l)):
            p = True
            for d in primes:
                if(d > sqrt(l[j])):
                    break
                if(l[j] % d == 0):
                    p = False
                    break;
            if(p):
                primes.append(l[j])

        return primes

    @profile
    def factorize(n,primes):
        factors = []
        init_n = n
        for p in primes:
            while(n%p == 0):
                n = n/p
                factors.append(p)
            if(p > sqrt(n)):
                break
        if(n > 1):
            factors.append(n)
        return factors

        
    def phi(n,primes):
        factors = factorize(n,primes)
        p = 1

        for i in range(2,n):
            flag = True
            for f in factors:
                if i%f == 0:
                    flag = False
                    break
            if flag:
                p+=1
        return p

    @profile
    def fast_phi(n,primes):
        factors = factorize(n,primes)
        phi = factors[0]-1
        for i in range(1,len(factors)):
            if(factors[i] == factors[i-1]):
                phi *= (factors[i]-1)*(factors[i])/(factors[i]-1)
            else:
                phi *= (factors[i]-1)
        return phi

    primes = gen_primes(1000)
    m = 10000
    #m = 8
    fraq = 0
    for i in range(2,m+1):
        fraq += fast_phi(i,primes)

    print(fraq)

# %%
# %load_ext memory_profiler

# %%
# %load_ext line_profiler

# %%
# import matmult
# matmult.test_matmult(250)
# %lprun -f testEuler testEuler()
# Out:
# 30397485.0
# Timer unit: 1e-07 s
#
# Total time: 0.355897 s
# File: C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# Function: testEuler at line 16
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     16                                           def testEuler():
#     17         1         21.0     21.0      0.0      @profile
#     18         1        361.0    361.0      0.0      def gen_primes(n):
#     19                                                   l = range(2,n)
#     20                                                   primes = []
#     21                                                   for j in range(0,len(l)):
#     22                                                       p = True
#     23                                                       for d in primes:
#     24                                                           if(d > sqrt(l[j])):
#     25                                                               break
#     26                                                           if(l[j] % d == 0):
#     27                                                               p = False
#     28                                                               break;
#     29                                                       if(p):
#     30                                                           primes.append(l[j])
#     31
#     32                                                   return primes
#     33
#     34         1         11.0     11.0      0.0      @profile
#     35         1        139.0    139.0      0.0      def factorize(n,primes):
#     36                                                   factors = []
#     37                                                   init_n = n
#     38                                                   for p in primes:
#     39                                                       while(n%p == 0):
#     40                                                           n = n/p
#     41                                                           factors.append(p)
#     42                                                       if(p > sqrt(n)):
#     43                                                           break
#     44                                                   if(n > 1):
#     45                                                       factors.append(n)
#     46                                                   return factors
#     47
#     48
#     49         1         13.0     13.0      0.0      def phi(n,primes):
#     50                                                   factors = factorize(n,primes)
#     51                                                   p = 1
#     52
#     53                                                   for i in range(2,n):
#     54                                                       flag = True
#     55                                                       for f in factors:
#     56                                                           if i%f == 0:
#     57                                                               flag = False
#     58                                                               break
#     59                                                       if flag:
#     60                                                           p+=1
#     61                                                   return p
#     62
#     63         1          9.0      9.0      0.0      @profile
#     64         1        132.0    132.0      0.0      def fast_phi(n,primes):
#     65                                                   factors = factorize(n,primes)
#     66                                                   phi = factors[0]-1
#     67                                                   for i in range(1,len(factors)):
#     68                                                       if(factors[i] == factors[i-1]):
#     69                                                           phi *= (factors[i]-1)*(factors[i])/(factors[i]-1)
#     70                                                       else:
#     71                                                           phi *= (factors[i]-1)
#     72                                                   return phi
#     73
#     74         1      91796.0  91796.0      2.6      primes = gen_primes(1000)
#     75         1          9.0      9.0      0.0      m = 10000
#     76                                               #m = 8
#     77         1          7.0      7.0      0.0      fraq = 0
#     78     10000      78260.0      7.8      2.2      for i in range(2,m+1):
#     79      9999    3386936.0    338.7     95.2          fraq += fast_phi(i,primes)
#     80
#     81         1       1279.0   1279.0      0.0      print(fraq)
#
# Total time: 0.00557 s
# File: C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# Function: gen_primes at line 17
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     17                                               @profile
#     18                                               def gen_primes(n):
#     19         1         12.0     12.0      0.0          l = range(2,n)
#     20         1          5.0      5.0      0.0          primes = []
#     21       999       3179.0      3.2      5.7          for j in range(0,len(l)):
#     22       998       3052.0      3.1      5.5              p = True
#     23      2968       9493.0      3.2     17.0              for d in primes:
#     24      2967      17201.0      5.8     30.9                  if(d > sqrt(l[j])):
#     25       167        551.0      3.3      1.0                      break
#     26      2800      12845.0      4.6     23.1                  if(l[j] % d == 0):
#     27       830       2651.0      3.2      4.8                      p = False
#     28       830       2704.0      3.3      4.9                      break;
#     29       998       3037.0      3.0      5.5              if(p):
#     30       168        967.0      5.8      1.7                  primes.append(l[j])
#     31
#     32         1          3.0      3.0      0.0          return primes
#
# Total time: 0.141715 s
# File: C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# Function: factorize at line 34
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     34                                               @profile
#     35                                               def factorize(n,primes):
#     36      9999      26476.0      2.6      1.9          factors = []
#     37      9999      27193.0      2.7      1.9          init_n = n
#     38     96347     263773.0      2.7     18.6          for p in primes:
#     39    118736     406942.0      3.4     28.7              while(n%p == 0):
#     40     22389      74381.0      3.3      5.2                  n = n/p
#     41     22389      83520.0      3.7      5.9                  factors.append(p)
#     42     96347     412040.0      4.3     29.1              if(p > sqrt(n)):
#     43      9999      29789.0      3.0      2.1                  break
#     44      9999      29988.0      3.0      2.1          if(n > 1):
#     45      9596      37230.0      3.9      2.6              factors.append(n)
#     46      9999      25821.0      2.6      1.8          return factors
#
# Total time: 0.289759 s
# File: C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# Function: fast_phi at line 63
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     63                                               @profile
#     64                                               def fast_phi(n,primes):
#     65      9999    2499261.0    250.0     86.3          factors = factorize(n,primes)
#     66      9999      39841.0      4.0      1.4          phi = factors[0]-1
#     67     31985     124652.0      3.9      4.3          for i in range(1,len(factors)):
#     68     21986      97215.0      4.4      3.4              if(factors[i] == factors[i-1]):
#     69      7685      44805.0      5.8      1.5                  phi *= (factors[i]-1)*(factors[i])/(factors[i]-1)
#     70                                                       else:
#     71     14301      64910.0      4.5      2.2                  phi *= (factors[i]-1)
#     72      9999      26908.0      2.7      0.9          return phi

# %%
# %mprun -f testEuler testEuler()
# Out:
# ERROR: Could not find file C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# ERROR: Could not find file C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# ERROR: Could not find file C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# ERROR: Could not find file C:\Users\jinxu785\AppData\Local\Temp/ipykernel_21468/454576193.py
# 30397485.0

# %%
# %prun testEuler()
# Out:
# 30397485.0
#          221564 function calls (211565 primitive calls) in 0.385 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      9999    0.245    0.000    0.261    0.000 454576193.py:34(factorize)
#      9999    0.077    0.000    0.354    0.000 454576193.py:63(fast_phi)
# 19999/10000    0.027    0.000    0.381    0.000 line_profiler.py:89(wrapper)
#     99314    0.013    0.000    0.013    0.000 {built-in method math.sqrt}
#         1    0.010    0.010    0.011    0.011 454576193.py:17(gen_primes)
#         1    0.004    0.004    0.385    0.385 454576193.py:16(testEuler)
#     32153    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#     19999    0.003    0.000    0.003    0.000 {method 'disable_by_count' of 'line_profiler._line_profiler.LineProfiler' objects}
#     19999    0.002    0.000    0.002    0.000 {method 'enable_by_count' of 'line_profiler._line_profiler.LineProfiler' objects}
#     10002    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 socket.py:474(send)
#         1    0.000    0.000    0.385    0.385 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 line_profiler.py:86(wrap_function)
#         3    0.000    0.000    0.000    0.000 iostream.py:206(schedule)
#         3    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         2    0.000    0.000    0.000    0.000 iostream.py:500(write)
#         1    0.000    0.000    0.385    0.385 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 line_profiler.py:46(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.000    0.000 threading.py:1113(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#         3    0.000    0.000    0.000    0.000 {method 'add_function' of 'line_profiler._line_profiler.LineProfiler' objects}
#         3    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#         3    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#         3    0.000    0.000    0.000    0.000 line_profiler.py:35(is_generator)
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 line_profiler.py:28(is_coroutine)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
